# %%
import pandas
import matplotlib.pyplot as plt
df1=pandas.read_csv('cereal.csv', sep=';')

print(df1)

print(df1['calories'])



df1['calories'].plot()
# Out:
#                                       name          mfr         type calories  \
# 0                                   String  Categorical  Categorical      Int
# 1                                100% Bran            N            C       70
# 2                        100% Natural Bran            Q            C      120
# 3                                 All-Bran            K            C       70
# 4                All-Bran with Extra Fiber            K            C       50
# 5                           Almond Delight            R            C      110
# 6                  Apple Cinnamon Cheerios            G            C      110
# 7                              Apple Jacks            K            C      110
# 8                                  Basic 4            G            C      130
# 9                                Bran Chex            R            C       90
# 10                             Bran Flakes            P            C       90
# 11                            Cap'n'Crunch            Q            C      120
# 12                                Cheerios            G            C      110
# 13                   Cinnamon Toast Crunch            G            C      120
# 14                                Clusters            G            C      110
# 15                             Cocoa Puffs            G            C      110
# 16                               Corn Chex            R            C      110
# 17                             Corn Flakes            K            C      100
# 18                               Corn Pops            K            C      110
# 19                           Count Chocula            G            C      110
# 20                      Cracklin' Oat Bran            K            C      110
# 21                  Cream of Wheat (Quick)            N            H      100
# 22                                 Crispix            K            C      110
# 23                  Crispy Wheat & Raisins            G            C      100
# 24                             Double Chex            R            C      100
# 25                             Froot Loops            K            C      110
# 26                          Frosted Flakes            K            C      110
# 27                     Frosted Mini-Wheats            K            C      100
# 28  Fruit & Fibre Dates, Walnuts, and Oats            P            C      120
# 29                           Fruitful Bran            K            C      120
# ..                                     ...          ...          ...      ...
# 48                    Multi-Grain Cheerios            G            C      100
# 49                        Nut&Honey Crunch            K            C      120
# 50               Nutri-Grain Almond-Raisin            K            C      140
# 51                       Nutri-grain Wheat            K            C       90
# 52                    Oatmeal Raisin Crisp            G            C      130
# 53                   Post Nat. Raisin Bran            P            C      120
# 54                              Product 19            K            C      100
# 55                             Puffed Rice            Q            C       50
# 56                            Puffed Wheat            Q            C       50
# 57                      Quaker Oat Squares            Q            C      100
# 58                          Quaker Oatmeal            Q            H      100
# 59                             Raisin Bran            K            C      120
# 60                         Raisin Nut Bran            G            C      100
# 61                          Raisin Squares            K            C       90
# 62                               Rice Chex            R            C      110
# 63                           Rice Krispies            K            C      110
# 64                          Shredded Wheat            N            C       80
# 65                  Shredded Wheat 'n'Bran            N            C       90
# 66               Shredded Wheat spoon size            N            C       90
# 67                                  Smacks            K            C      110
# 68                               Special K            K            C      110
# 69                 Strawberry Fruit Wheats            N            C       90
# 70                       Total Corn Flakes            G            C      110
# 71                       Total Raisin Bran            G            C      140
# 72                       Total Whole Grain            G            C      100
# 73                                 Triples            G            C      110
# 74                                    Trix            G            C      110
# 75                              Wheat Chex            R            C      100
# 76                                Wheaties            G            C      100
# 77                     Wheaties Honey Gold            G            C      110
#
#    protein  fat sodium  fiber  carbo sugars potass vitamins shelf weight  \
# 0      Int  Int    Int  Float  Float    Int    Int      Int   Int  Float
# 75       3    1    230      3     17      3    115       25     1      1
# 76       3    1    200      3     17      3    110       25     1      1
# 77       2    1    200      1     16      8     60       25     1      1
#
#      cups     rating
# 0   Float      Float
# 1    0.33  68.402973
# 2       1  33.983679
# 3    0.33  59.425505
# 4     0.5  93.704912
# 5    0.75  34.384843
# 6    0.75  29.509541
# 7       1  33.174094
# 8    0.75  37.038562
# 9    0.67  49.120253
# 10   0.67  53.313813
# 11   0.75  18.042851
# 12   1.25  50.764999
# 13   0.75  19.823573
# 14    0.5  40.400208
# 15      1  22.736446
# 16      1  41.445019
# 17      1  45.863324
# 18      1  35.782791
# 19      1  22.396513
# 20    0.5  40.448772
# 21      1  64.533816
# 22      1  46.895644
# 23   0.75  36.176196
# 24   0.75  44.330856
# 25      1  32.207582
# 26   0.75  31.435973
# 27    0.8  58.345141
# 28   0.67  40.917047
# 29   0.67  41.015492
# ..    ...        ...
# 48      1  40.105965
# 49   0.67  29.924285
# 50   0.67  40.692320
# 51      1  59.642837
# 52    0.5  30.450843
# 53   0.67  37.840594
# 54      1  41.503540
# 55      1  60.756112
# 56      1  63.005645
# 57    0.5  49.511874
# 58   0.67  50.828392
# 59   0.75  39.259197
# 60    0.5  39.703400
# 61    0.5  55.333142
# 62   1.13  41.998933
# 63      1  40.560159
# 64      1  68.235885
# 65   0.67  74.472949
# 66   0.67  72.801787
# 67   0.75  31.230054
# 68      1  53.131324
# 69      1  59.363993
# 70      1  38.839746
# 71      1  28.592785
# 72      1  46.658844
# 73   0.75  39.106174
# 74      1  27.753301
# 75   0.67  49.787445
# 76      1  51.592193
# 77   0.75  36.187559
#
# [78 rows x 16 columns]
# 0     Int
# 1      70
# 2     120
# 3      70
# 4      50
# 5     110
# 6     110
# 7     110
# 8     130
# 9      90
# 10     90
# 11    120
# 12    110
# 13    120
# 14    110
# 15    110
# 16    110
# 17    100
# 18    110
# 19    110
# 20    110
# 21    100
# 22    110
# 23    100
# 24    100
# 25    110
# 26    110
# 27    100
# 28    120
# 29    120
#      ...
# 48    100
# 49    120
# 50    140
# 51     90
# 52    130
# 53    120
# 54    100
# 55     50
# 56     50
# 57    100
# 58    100
# 59    120
# 60    100
# 61     90
# 62    110
# 63    110
# 64     80
# 65     90
# 66     90
# 67    110
# 68    110
# 69     90
# 70    110
# 71    140
# 72    100
# 73    110
# 74    110
# 75    100
# 76    100
# 77    110
# Name: calories, Length: 78, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-bf9c96738132> in <module>()
#       7 print(df1['calories'])
#       8
# ----> 9 df1['calories'].plot()
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2451                            colormap=colormap, table=table, yerr=yerr,
#    2452                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2453                            **kwds)
#    2454     __call__.__doc__ = plot_series.__doc__
#    2455
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1892                  yerr=yerr, xerr=xerr,
#    1893                  label=label, secondary_y=secondary_y,
# -> 1894                  **kwds)
#    1895
#    1896
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
# -> 1694     plot_obj.generate()
#    1695     plot_obj.draw()
#    1696     return plot_obj.result
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     241     def generate(self):
#     242         self._args_adjust()
# --> 243         self._compute_plot_data()
#     244         self._setup_subplots()
#     245         self._make_plot()
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     350         if is_empty:
#     351             raise TypeError('Empty {0!r}: no numeric data to '
# --> 352                             'plot'.format(numeric_data.__class__.__name__))
#     353
#     354         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
df1['calories']=df1.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f1db00ba0838> in <module>()
# ----> 1 df1['calories']=df1.astype(float)
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, raise_on_error, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     634
#     635     if copy:
# --> 636         return arr.astype(dtype)
#     637     return arr.view(dtype)
#     638
#
# ValueError: could not convert string to float: 'Float'

# %%
import pandas
import matplotlib.pyplot as plt

df1=pandas.read_csv('cereal.csv', sep=';')

#print(df1)

#print(df1['calories'])

#df1['calories']=df1.astype(int)

print('---------------------------')

df1['calories']=df1['calories'].convert_objects(convert_numeric=True)
print(df1['calories'].convert_objects(convert_numeric=True).dtypes)

print(df1['calories'].dtypes)

#df1['calories'].convert_objects(convert_numeric=True).dtypes

#print(df1['calories'])

print(df1['calories'].plot())
# Out:
# ---------------------------
# float64
# float64
# AxesSubplot(0.125,0.125;0.775x0.755)
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# c:\users\mike kyle\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app

# %%
print(df1['calories'].plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
